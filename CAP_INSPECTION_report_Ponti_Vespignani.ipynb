# %% [markdown]
# ### Image Processing and Computer Vision - Project
# ## CAP INSPECTION - Project 1 : Plastic cap liner inspection
# ### *Lucrezia Ponti, Thomas Vespignani*
#
# **Project objective:** Locate the defects in the liner of a plastic cap.
# #### Tasks:
# 1. **Cap segmentation and defect detection**<br>
#    **1.1** Outline the cap by generating a circle that fits the cap mouth and record the following information:
#    - the position of the center of the cap
#    - the diameter of the cap mouth
#
#    **1.2** Find if the liner is missing and if it is not, find if the liner has a defect
#
# 2. **Liner segmentation**<br>
#    Outline the liner by generating a circle that fits the liner border and record the following information:
#    - the position of the center of the liner
#    - the diameter of the liner
#
# **Optional requirement:**
# Outline the straight edge of the liner's defect.

# %% [markdown]
# ### Code Setup
# To make the code more flexible, in the following cell two variables can be modified:
# - *img_name*: select the image to be inspected
# - *show_steps*: show all images of the intermediate results (True) or only the final results of each task (False)

# %%
img_name = "d_18"
show_steps = False

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import math

liner_flag = False
defect_flag = False
final_results= ""

# %% [markdown]
# The image is loaded as colored, which is useful to efficiently show the results, but since for the functions used in the computation a grayscale image is required, we create a copy as such.

# %%
img_color = cv2.imread("cap-inspection-images/project_1_liner_inspection/"+img_name+".bmp")
img = cv2.cvtColor(img_color,cv2.COLOR_BGR2GRAY)
if show_steps :
    plt.figure()
    plt.title("Original image "+img_name)
    plt.imshow(img,cmap='gray',vmin=0,vmax=255)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Enhancing the image
# In many Computer Vision applications an initial step of image processing is often added to improve the quality of the image and enhance the details useful for the specific objectives. <br>
#
# In this case, it can be oberved that the gray-scale histogram of the images is generally confined to a small range (about $[0;100]$), see Figure below.
#
# Since we have to inspect the gradient to perform the computations, it is useful to enlarge the histogram range and therefore improve the contrast of the image. <br>
# To do this, the Contrast Limited Adaptive Histogram Equalization (CLAHE) can be used [[Documentation](https://docs.opencv.org/4.x/d5/daf/tutorial_py_histogram_equalization.html)].
# This function divides the image into "tiles", whose size is set with the parameter *tileGridSize*, and for each performs a linear histogram equalization. To avoid amplifying noise, a limit on the contrast is applied: for each tile's histogram, before applying the equalization, if any bin has value above the limit (specified with the parameter *clipLimit*) it is clipped and the excess is redistribuited uniformly to other bins. Finally, to remove artifacts in tile borders, bilinear interpolation is applied.
#
# We obtain an image with a better distributed histogram, without amplifying noise or creating artifacts.
#
# <div style="display: flex;justify-content: center; gap: 10px;">
#     <img src="report_pictures/d_18.png" alt="image d_18" height="220"/>
#     <img src="report_pictures/hist_d_18.png" alt="histogram of image d_18" height="220"/>
#     <img src="report_pictures/hist_d_18_clahe.png" alt="enhanced histogram of image d_18" height="220"/>
# </div>
#
# Additionally, to remove noise and becuse it is needed for the Canny edge detector used in the following steps, a Gaussian filter is applied. The filter's kernel size is choosen to 7x7 and the value of $\sigma$ is set to 1.5, to have a stronger blurring effect with respect to the one that we would have obtained using the value ($\sigma$=1) suggested by the rule of thumb.

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(5,5))
img_cl = clahe.apply(img)
img_blur = cv2.GaussianBlur(img_cl,(7,7),1.5)

if show_steps :
    plt.figure()
    plt.title("Enhanced image")
    plt.imshow(img_blur,cmap="gray",vmin=0,vmax=255)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Task 1: Cap segmentation and defect detection
#
#
# ### 1.1 Segmentation of the cap mouth
# Following the hint given, the function *HoughCircles* is used to detect the cap mouth [[Documentation](https://docs.opencv.org/4.x/dd/d1a/group__imgproc__feature.html#ga47849c3be0d0406ad3ca45db65a25d2d)]. <br>
# The function applies Canny edge detector as a first step and uses the Hough Transform theory for circles. This theory uses the equation of analytical shapes and evaluates edge pixels by mapping them into a parameter space accumulator. Since the equation of the circle has 3 parameters, it would require a 3D accumulator, which is highly inefficient. Instead, the Hough Gradient Method is used, which is trickier but more efficient.<br>
# The most important parameters of the function are:
# - *minDist*: minimum distance between the centers of the detected circles;
# - *param1*: higher threshold of the Canny edge detector (the lower threshold is computed as half the higher);
# - *param2*:	accumulator threshold for the circle centers, the smaller it is, the more imperfect, or even false, circles will be detected.
#
# In particular, *param1* is chosen to 110 so that Canny will find the cap mouth outer contur, which has a very strong gradient, and barely any other edges inside.
#
# The *HoughCircles* function returns a list containing the circle's center position and radius for each of the detected circles, sorted in descending order based on their accumulator value. Therefore, the first circle in the list corresponds to the most accurate detection of the cap mouth contour.

# %%
circles_out = cv2.HoughCircles(img_blur,cv2.HOUGH_GRADIENT, 1, 40,param1=110,param2=80) 
center_out = (circles_out[0][0][0],circles_out[0][0][1])
radius_out = circles_out[0][0][2]

img_color_out=img_color.copy()
cv2.circle(img_color_out,(int(center_out[0]),int(center_out[1])),int(radius_out),color=(0, 255, 0),thickness=2)
cv2.circle(img_color_out,(int(center_out[0]),int(center_out[1])),int(2),color=(0, 255, 0),thickness=2)

print("CAP MOUTH OUTLINE \n Center: x = ", center_out[0]," y = ",center_out[1]," \n Diameter = ",radius_out*2 )
plt.imshow(img_color_out)
plt.axis('off')
plt.show()


img_color_final=img_color.copy() # gather results of all tasks
cv2.circle(img_color_final,(int(center_out[0]),int(center_out[1])),int(radius_out),color=(0, 255, 0),thickness=2)
cv2.circle(img_color_final,(int(center_out[0]),int(center_out[1])),int(2),color=(0, 255, 0),thickness=2)
final_results=final_results+"CAP MOUTH OUTLINE\n Center: x = "+str(center_out[0])+" y = "+str(center_out[1])+" - Diameter = "+str(radius_out*2) + " \n"
# Out:
# CAP MOUTH OUTLINE
#  Center: x =  382.5  y =  287.5
#  Diameter =  509.2

# %% [markdown]
# ### 1.2 Liner inspection
# To get clearer information about the liner, it is useful to consider only a Region Of Interest (ROI) inside the cap mouth.
# The dimension of the ROI has been chosen empirically to be a fraction of the radius of the cap mouth obtained in the previous step, so that the liner area is shown properly.
#
# Fistly, we need to find whether the liner is present or not. <br>
# Following the hint given, the average lightness of each image should be inspected. Doing so, it can be observed that for caps that have the liner this value is about 97 and for caps without the liner (image d_31) it is about 107. Therefore, a threshold value can be fixed (for example to 102) to evaluate the average lightness to validate the presence of the liner. This could be implemented as such:
# ```
# avg=cv2.mean(img_roi)[0]
# if avg>102 :
#     print("NO LINER")
# else :
#     # continue computation
# ```
#
# However, considering to evaluate only one image at a time, it may be better to find a method that does not rely so heavily on other images' information.
#
# We observed that when the liner is present it creates a darker shadow at its border, which can easily be detected as a circular edge.
# By applying the *HoughCircles* function with *param1*= 100 (which is more "permissive" than the value used for cap mouth detection) the edge map obtained with Canny will show the liner contour, if present, and therefore the Hough Transform will manage to detect a circle. If no liner is present, the shadow is not as dark and therefore no edge within the cap will show in the edge map, so no circle will be found. <br>
# This allows us to also find immediately the infomation about the liner, position of the center and diameter, needed for the second task.
#
# <div style="display: flex;justify-content: center; gap: 10px;">
#     <img src="report_pictures/canny_liner_d_18.png" alt="edge map of d_18" height="250"/>
#     <img src="report_pictures/canny_liner_d_31.png" alt="edge map of d_31" height="250"/>
# </div>
#
# Secondly, if the liner is found we need to inspect it to detect possible defects. <br>
# The defects to be detected consist in a linear cut of the liner, therefore they can be directly identified by using the Hough Tranform for line detection. The function in OpenCV to do this is *HoughLines* [[Documentation](https://docs.opencv.org/3.4/d9/db0/tutorial_hough_lines.html)]. Differently from *HoughCirles*,  the *HoughLines* function requires a Canny edge detector to be called previously because it does not include it in its own computation. <br>
# The Canny edge detector in this part needs to have lower thresholds because the edges of these details have a lower gradient magnitude, so its parameters have been set accordingly to 80, for the higher threshold, and 40, for the lower [[Documentation](https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html)]. <br>
# The parameters of the *HoughLines* function have been chosen to detect lines in any position and orientation, but, by setting the final parameter (the accumulator threshold) to 70, limiting the detection to long, distinguishable lines.<br>
# Similarly to *HoughCircles*, the detected lines' information are returned as a list sorted in descending order of the accumulator value, so the first one can be considered the best candidate to identify the defect. If no lines are detected, it indicates that no defect is present in the liner.

# %%
offset = radius_out*0.8 
x_max_roi=math.ceil(center_out[0]+offset)
x_min_roi=math.floor(center_out[0]-offset)
y_max_roi=math.ceil(center_out[1]+offset)
y_min_roi=math.floor(center_out[1]-offset)  
img_roi=img_blur[y_min_roi:y_max_roi,x_min_roi:x_max_roi]
img_roi_show=cv2.cvtColor(img_roi, cv2.COLOR_GRAY2RGB) 


circles_in = cv2.HoughCircles(img_roi,cv2.HOUGH_GRADIENT, 1, 50,param1=100,param2=80) 

line_layer=np.zeros_like(img_color) # for the optional requirement

if circles_in is not None and len(circles_in) > 0: 
    
    print("LINER FOUND")
    liner_flag= True

    edges = cv2.Canny(img_roi,40,80,apertureSize = 3)
    if show_steps :
        plt.figure()
        plt.title("Edge map of ROI")
        plt.imshow(edges,cmap='gray',vmin=0,vmax=255)
        plt.axis('off')
        plt.show() 
    

    lines = cv2.HoughLines(edges,1,np.pi/180,70)
    if lines is not None and len(lines) > 0:    
        
        print("LINER DEFECT FOUND")
        final_results=final_results+"LINER DEFECTS FOUND \n"
        defect_flag= True

        rho, theta = lines[0][0] 
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))

        cv2.line(line_layer, (x1+x_min_roi, y1+y_min_roi), (x2+x_min_roi, y2+y_min_roi), (0, 0, 255), 2) # useful for the optional requirement
        
        if show_steps :
            cv2.line(img_roi_show, (x1, y1), (x2, y2), (0, 0, 255), 2)
            plt.figure()
            plt.title("Defect line found")
            plt.imshow(img_roi_show)
            plt.axis('off')
            plt.show()
        
    else: 
        print("NO LINER DEFECTS FOUND") 
        final_results=final_results+"NO LINER DEFECTS FOUND \n"

else : 
    print("NO LINER FOUND") 
    final_results=final_results+"NO LINER FOUND \n"
# Out:
# LINER FOUND
# LINER DEFECT FOUND

# %% [markdown]
# ## Task 2 : Liner segmentation
# If the liner is present, its outline has to be shown in the image and the information about the position of its center and its diameter have to be recorded.
#
# These information can be retreived from the results obtained in the previous step, with the function *HoughCircles* applied on the ROI.<br>
# It is important to translate the position of the center of the circle back to the coordinates of the original image to have information coherent with that of the cap mouth.

# %%
circle_liner_layer=np.zeros_like(img_color) # useful for the optional requirement

if liner_flag: 

    center_in = (circles_in[0][0][0]+x_min_roi,circles_in[0][0][1]+y_min_roi)
    radius_in = circles_in[0][0][2]
    
    cv2.circle(circle_liner_layer,(int(center_in[0]),int(center_in[1])),int(radius_in),color=(255,0, 0),thickness=2) # useful for the optional requirement

    if show_steps: 
        cv2.circle(img_roi_show,(int(center_in[0]-x_min_roi),int(center_in[1]-y_min_roi)),int(radius_in),color=(255, 0, 0),thickness=2)
        cv2.circle(img_roi_show,(int(center_in[0]-x_min_roi),int(center_in[1]-y_min_roi)),int(2),color=(255,0, 0),thickness=2)
        plt.figure()
        plt.title("Liner outline in ROI")
        plt.imshow(img_roi_show)
        plt.axis('off')
        plt.show()

    img_color_in=img_color.copy()
    cv2.circle(img_color_in,(int(center_in[0]),int(center_in[1])),int(radius_in),color=(255, 0, 0),thickness=2)
    cv2.circle(img_color_in,(int(center_in[0]),int(center_in[1])),int(2),color=(255, 0, 0),thickness=2)

    print("LINER OUTLINE\n Center: x = ", center_in[0]," y = ",center_in[1],"\n Diameter = ",radius_in*2)
    plt.figure()
    plt.imshow(img_color_in)
    plt.axis('off')
    plt.show()


    cv2.circle(img_color_final,(int(center_in[0]),int(center_in[1])),int(radius_in),color=(255, 0, 0),thickness=2)
    cv2.circle(img_color_final,(int(center_in[0]),int(center_in[1])),int(2),color=(255, 0, 0),thickness=2)
    final_results=final_results+"LINER OUTLINE\n Center: x = "+str(center_in[0])+" y = "+str(center_in[1])+" - Diameter = "+str(radius_in*2) + " \n"
# Out:
# LINER OUTLINE
#  Center: x =  383.5  y =  285.5
#  Diameter =  375.8

# %% [markdown]
# ## Optional requirement
# Outline the straight edge of the defect of the liner, where present.
#
# In the step 1.2, two dedicated empty images, *cirle_liner_layer* and *line_layer*, were created. <br>
# When the defect line is detected, it is drawn in blue on *line_layer*, while, when the liner contour is found, it is drawn as a red circle on *circle_liner_layer*.
#
# Since the line detected by *HoughLines* is theoretically infinite and does not correspond to the actual defect segment, its extremes must be determined.
# The line intersects the circle representing the contour of the liner, so the intersection points are the extremes of the segment.<br>
# To find their coordinates in the image we can combine the two layers to obtain a new image (*liner_layer*) which contains a blue line, a red circle and pink pixels at their intersection.
# By creating a mask that extracts only the pink pixels and using the function *where*, we obtain two arrays containing their coordinates.
# Due to the thickness of the lines, multiple pixels are detected for each intersection and so we have to choose one for each, which can be done simply by taking the first and last elements of the arrays.
#
# Once found the coordinates of the intersections, we can use them to create a rectangle surrounding the segment. <br>
# A method to do this consists in finding the unitary vectors representing the direction perpendicular to the segment. Then the four corners of the rectangle are calculated by multipliying these vectors by a desired width and adding (or subtracting) them to the extremes coordinates. <br>
# To show the rectangle on the image, the function *polylines* is used.

# %%
if defect_flag:
    liner_layer=line_layer+circle_liner_layer
    mask = np.all(liner_layer == np.array([255, 0, 255], dtype=np.uint8), axis=2)
    y, x = np.where(mask) 

    x1=x[0]
    y1=y[0]
    x2=x[-1]
    y2=y[-1]

    dx = x2-x1
    dy = y2-y1
    length = math.sqrt(dx**2+dy**2)

    if length>0:
        nx = -dy/length
        ny = dx/length
        
        width = 15
        pt1 = [x1+width*nx, y1+width*ny]
        pt2 = [x1-width*nx, y1-width*ny]
        pt3 = [x2-width*nx, y2-width*ny]
        pt4 = [x2+width*nx, y2+width*ny]
        
        pts = np.array([pt1, pt2, pt3, pt4], dtype=np.int32)
        
        img_color_rect=img_color.copy()
        cv2.polylines(img_color_rect, [pts], isClosed=True, color=(255, 0, 255), thickness=2)
    
        plt.figure()
        plt.title("Defect outline")
        plt.imshow(img_color_rect)
        plt.axis('off')
        plt.show()


        cv2.polylines(img_color_final, [pts], isClosed=True, color=(255, 0, 255), thickness=2)

# %% [markdown]
# ## Final results

# %%
print(final_results)
plt.figure()
plt.title("Final result for image "+img_name)
plt.imshow(img_color_final)
plt.axis('off')
plt.show()
# Out:
# CAP MOUTH OUTLINE
#  Center: x = 382.5 y = 287.5 - Diameter = 509.2
# LINER DEFECTS FOUND
# LINER OUTLINE
#  Center: x = 383.5 y = 285.5 - Diameter = 375.8

# %% [markdown]
# The results obtained for each image are collected in the following table, along with a few additional observations:
#
# <img src="report_pictures/results_recap.png" alt="Table containing values obtained for all images" height="300"/>
#
# It can be observed that all the requested information are extracted correctly, there are no false positives or false negatives, and with acceptable accuracy. <br>
# In particular, if we assume that ideally the center of the cap mouth and that of the liner should be corresponding but we allow for a small error, the results obtained can be considered acceptable: the distance of the centers has an average of 2.86 pixels and never exceeds 4.5 pixels, which is less than 1% of the measured diameter of the cap mouth.
#
# In conclusion, the program implemented allows to correctly and efficiently locate the plastic cap, its liner and possible defects of the latter.
